# %%
from thinkdsp import read_wave

wave1 = read_wave('do.wav')
wave1.normalize()
wave1.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave2 = read_wave('do_major.wav')
wave2.normalize()
wave2.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave1.plot()
wave2.plot()

# %%
segment1 = wave1.segment(start=1.1, duration=0.3)
segment1.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
segment2 = wave2.segment(start=1.1, duration=0.3)
segment2.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
segment1.plot()
segment2.plot()

# %%
segment1.segment(start=1.1, duration=0.005).plot()
segment2.segment(start=1.1, duration=0.005).plot()

# %%
spectrum1 = segment1.make_spectrum()
spectrum1.plot(high=7000)
spectrum2 = segment2.make_spectrum()
spectrum2.plot(high=7000)

# %%
spectrum1 = segment1.make_spectrum()
spectrum1.plot(high=1000)
spectrum2 = segment2.make_spectrum()
spectrum2.plot(high=1000)

# %%
do = spectrum1.peaks()[:30]
print(do[:30])
# Out:
# [(507.13689818005713, 260.0), (360.8433795236427, 263.33333333333337), (148.04255816469464, 256.6666666666667), (146.1814476940448, 1313.3333333333335), (129.68129661758044, 266.6666666666667), (119.80495136879385, 916.6666666666667), (89.75151861121114, 653.3333333333334), (86.42649645587777, 130.0), (82.00302631147724, 270.0), (77.09205811391115, 253.33333333333334), (76.42499810050467, 1580.0), (62.923442510190846, 1983.3333333333335), (58.67613309078261, 250.0), (57.057460559584506, 273.33333333333337), (52.08963302778938, 523.3333333333334), (48.317716329043265, 1713.3333333333335), (46.680571711038056, 393.33333333333337), (46.19625968564035, 246.66666666666669), (43.60251443961951, 276.6666666666667), (40.742428519518995, 1966.6666666666667), (38.1103301312849, 243.33333333333334), (37.42990131237253, 280.0), (33.70103793266305, 390.0), (32.2238192185273, 240.0), (31.387980477471935, 1180.0), (31.22366405200878, 283.33333333333337), (27.988358265269653, 236.66666666666669), (26.7978427511309, 286.6666666666667), (25.93473758783878, 783.3333333333334), (24.426475314116978, 233.33333333333334)]

# %%
spectrum1.low_pass(2000)
spectrum1.make_wave().make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
do_major = spectrum2.peaks()[:30]
print(do_major[:30])
# Out:
# [(363.34194384245245, 260.0), (256.3490918314378, 263.33333333333337), (179.45611695874473, 393.33333333333337), (123.64992641336245, 390.0), (122.58802509457628, 330.0), (107.4052054480171, 256.6666666666667), (103.93482285641113, 1313.3333333333335), (91.0104072112159, 266.6666666666667), (87.84938820890746, 163.33333333333334), (85.21546019018416, 916.6666666666667), (72.95465680586533, 166.66666666666669), (68.37886245021984, 653.3333333333334), (63.642442407355254, 493.33333333333337), (58.798187167915096, 1580.0), (58.609255940027055, 130.0), (57.9987334846134, 193.33333333333334), (57.057595816456825, 270.0), (56.863610286959286, 253.33333333333334), (54.770539904937834, 396.6666666666667), (44.9531266566201, 783.3333333333334), (44.0804352452634, 250.0), (43.39773439896871, 386.6666666666667), (42.74809498477167, 1983.3333333333335), (41.65694844487284, 326.6666666666667), (40.29010725755495, 196.66666666666669), (39.04544939334821, 273.33333333333337), (37.90812820423881, 523.3333333333334), (37.83864481732399, 1180.0), (37.43273155979166, 1576.6666666666667), (35.317468424149375, 246.66666666666669)]

# %%
spectrum2.low_pass(2000)
spectrum2.make_wave().make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
for i in do:
    for x in do_major:
        if i[1] == x[1]:
            do_major.remove(x)


print(do_major)
# Out:
# []
